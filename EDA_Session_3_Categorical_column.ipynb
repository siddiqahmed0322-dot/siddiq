# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sys

visa=pd.read_csv(r"C:\Users\ADMIN\OneDrive\Documents\data science nit\Pandas\Visadataset.csv")
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **step-2:seperate cat and num columns**

# %%
cat=visa.select_dtypes(include='object').columns.tolist()
num=visa.select_dtypes(exclude='object').columns.tolist()
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %% [markdown]
# - frequency table
# - relative frequency table
# - bar chart
# - pie chart

# %% [markdown]
# **Step-3:Frequency Table**

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa['continent'].nunique()
# Out:
# 6

# %% [markdown]
# - There are 25480 applicants from  6 continent
# - number of application from each continent:**Frequency table**

# %%
visa      #df
visa['continent']  # one column
con=visa['continent']=='Asia'  # one class
np.sum(con)   #sum
visa[con]     #extraction
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# con=visa['continent']=='Asia'  # one class
# np.sum(con)

# con=visa['continent']=='Africa'  # one class
# np.sum(con)


# con_class=visa['continent']=='continent'  # one class
# np.sum(con)
cont_class=visa['continent'].unique()
freq=[]
for i in cont_class:
    con=visa['continent']==i
    freq.append(np.sum(con))

pd.DataFrame(zip(cont_class,freq),
            columns=['Class','Frequency'])
# Out:
#            Class  Frequency
# 0           Asia      16861
# 1         Africa        551
# 2  North America       3292
# 3         Europe       3732
# 4  South America        852
# 5        Oceania        192

# %%
visa['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa['continent'].keys()
# Out:
# RangeIndex(start=0, stop=25480, step=1)

# %%
visa['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %%
keys=visa.keys().tolist()
values=visa.dtypes.values.tolist()
cat,num=[],[]
for i,j in zip(keys,values):
    if j=='object':
        cat.append(i)
    else:
        num.append(i)
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
visa=pd.read_csv(r"C:\Users\ADMIN\OneDrive\Documents\data science nit\Pandas\Visadataset.csv")

keys=visa['continent'].value_counts().keys()
values=visa['continent'].value_counts().values
pd.DataFrame(zip(keys,values),
            columns=['continent','Frequency'])
# Out:
#        continent  Frequency
# 0           Asia      16861
# 1         Europe       3732
# 2  North America       3292
# 3  South America        852
# 4         Africa        551
# 5        Oceania        192

# %%
visa.groupby(by='continent').count()['case_id']
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# Name: case_id, dtype: int64

# %%
visa.groupby(by='continent').count()['education_of_employee']
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# Name: education_of_employee, dtype: int64

# %%
visa.groupby(by='education_of_employee').count()['case_status']
# Out:
# education_of_employee
# Bachelor's     10234
# Doctorate       2192
# High School     3420
# Master's        9634
# Name: case_status, dtype: int64

# %%
visa.groupby(by='no_of_employees').count()['has_job_experience']
# Out:
# no_of_employees
# -26        7
# -25        5
# -17        4
# -14        8
# -11        9
#           ..
#  547172    1
#  579004    1
#  581468    1
#  594472    1
#  602069    1
# Name: has_job_experience, Length: 7105, dtype: int64

# %%
# cont_class=visa['continent'].unique()
# freq=[]
# for i in cont_class:
#     con=visa['continent']==i
#     freq.append(np.sum(con))

# pd.DataFrame(zip(cont_class,freq),
#             columns=['Class','Frequency'])
cont_class=visa['region_of_employment'].unique()
freq=[]
for i in cont_class:
    con=visa['region_of_employment']==i
    freq.append(np.sum(con))
pd.DataFrame(zip(cont_class,freq),
            columns=['class','frequency'])
# Out:
#        class  frequency
# 0       West       6586
# 1  Northeast       7195
# 2      South       7017
# 3    Midwest       4307
# 4     Island        375

# %%
cont_class=visa['case_id'].unique()
freq=[]
for i in cont_class:
    con=visa['case_id']==i
    freq.append(np.sum(con))
pd.DataFrame(zip(cont_class,freq),
            columns=['class','frequency'])
# Out:
#            class  frequency
# 0         EZYV01          1
# 1         EZYV02          1
# 2         EZYV03          1
# 3         EZYV04          1
# 4         EZYV05          1
# ...          ...        ...
# 25475  EZYV25476          1
# 25476  EZYV25477          1
# 25477  EZYV25478          1
# 25478  EZYV25479          1
# 25479  EZYV25480          1
#
# [25480 rows x 2 columns]

# %%
cont_class=visa['case_id'].unique()
freq=[]
for i in cont_class:
    con=visa['case_id']==i
    freq.append(np.sum(con))
pd.DataFrame(zip(cont_class,freq),
            columns=['class','frequency'])
# Out:
#            class  frequency
# 0         EZYV01          1
# 1         EZYV02          1
# 2         EZYV03          1
# 3         EZYV04          1
# 4         EZYV05          1
# ...          ...        ...
# 25475  EZYV25476          1
# 25476  EZYV25477          1
# 25477  EZYV25478          1
# 25478  EZYV25479          1
# 25479  EZYV25480          1
#
# [25480 rows x 2 columns]

# %%
cont_class=visa['case_id'].unique()
freq=[]
for i in cont_class:
    con=visa['case_id']==i
    freq.append(np.sum(con))
pd.DataFrame(zip(cont_class,freq),
            columns=['class','frequency'])
# Out:
#            class  frequency
# 0         EZYV01          1
# 1         EZYV02          1
# 2         EZYV03          1
# 3         EZYV04          1
# 4         EZYV05          1
# ...          ...        ...
# 25475  EZYV25476          1
# 25476  EZYV25477          1
# 25477  EZYV25478          1
# 25478  EZYV25479          1
# 25479  EZYV25480          1
#
# [25480 rows x 2 columns]

# %%
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cont_class=visa['case_id'].unique()
freq=[]
for i in cont_class:
    con=visa['case_id']==i
    freq.append(np.sum(con))
pd.DataFrame(zip(cont_class,freq),
            columns=['class','frequency'])
freq
# Out:
# [np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
# ...

# %%
print('hello')
# Out:
# hello
