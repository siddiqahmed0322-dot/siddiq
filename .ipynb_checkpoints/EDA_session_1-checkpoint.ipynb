# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sys

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %% [markdown]
# **step-2:**

# %%
visa=pd.read_csv(r"C:\Users\ADMIN\OneDrive\Documents\data science nit\Pandas\Visadataset.csv")
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bank=pd.read_csv(r"C:\Users\ADMIN\OneDrive\Documents\data science nit\Pandas\bank.csv",sep=';')
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
visa.sample(5)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 17742  EZYV17743           Asia            Bachelor's                  N
# 18702  EZYV18703         Europe            Bachelor's                  N
# 17767  EZYV17768  North America              Master's                  Y
# 14838  EZYV14839           Asia              Master's                  Y
# 6328    EZYV6329           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 17742                     N             5460         1979
# 18702                     Y             3317         1966
# 17767                     N             1911         1888
# 14838                     N             1988         1986
# 6328                      N             1794         1913
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 17742            Northeast         68115.66         Year                  Y
# ...

# %%
visa.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
visa.describe(include='object')
# Out:
#        case_id continent education_of_employee has_job_experience  \
# count    25480     25480                 25480              25480
# unique   25480         6                     4                  2
# top     EZYV01      Asia            Bachelor's                  Y
# freq         1     16861                 10234              14802
#
#        requires_job_training region_of_employment unit_of_wage  \
# count                  25480                25480        25480
# unique                     2                    5            4
# top                        N            Northeast         Year
# freq                   22525                 7195        22962
#
#        full_time_position case_status
# count               25480       25480
# unique                  2           2
# top                     Y   Certified
# freq                22773       17018

# %% [markdown]
# **us visa_df**
#
# - visa_df_shape
# - visa_df_size
# - head
# - tail
# - dtypes
# - columns
# - null
# - info

# %%
visa.shape
# Out:
# (25480, 12)

# %%
visa.size
# Out:
# 305760

# %%
visa.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa.tail(3)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25477   Certified
# 25478   Certified
# 25479   Certified

# %%
visa.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
cols=visa.columns
cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
list(visa.columns)
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols=visa.columns.to_list()

# %%
cols.index('yr_of_estab')
# Out:
# 6

# %%
visa.isnull
# Out:
# <bound method DataFrame.isnull of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
visa.info
# Out:
# <bound method DataFrame.info of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
type(visa)
# Out:
# pandas.core.frame.DataFrame

# %%
visa  #pandas
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa.values #numpy arrays
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %%
visa.values.shape
# Out:
# (25480, 12)

# %% [markdown]
# **LOC-ILOC**

# %%
#visa.iloc[rows,columns]
#visa.iloc[start:stop:end,start:stop:end]
visa.iloc[2:6,3:7]
#row: 2:6  2,3,4,5
#columns: 3:7 3,4,5,6
# Out:
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
# 5                  Y                     N             2339         2012

# %%
# visa.iloc[2:6,3:7]

cols=['has_job_experience','requires_job_training']
visa.loc[2:6,cols]
# Out:
#   has_job_experience requires_job_training
# 2                  N                     Y
# 3                  N                     N
# 4                  Y                     N
# 5                  Y                     N
# 6                  N                     N

# %%
visa.iloc[[100,200,300]]
# visa.iloc[[100,200,300],:3]
# visa.iloc[[100,200,300],[3,9]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.iloc[[100,200,300],:3]
# Out:
#      case_id continent education_of_employee
# 100  EZYV101      Asia              Master's
# 200  EZYV201      Asia             Doctorate
# 300  EZYV301      Asia              Master's

# %%
visa.iloc[[100,200,300],[3,8]]
# Out:
#     has_job_experience  prevailing_wage
# 100                  Y         28243.79
# 200                  Y         74441.11
# 300                  Y        101371.21

# %%
#every  student should understand
# 1D and 2D
# list [] numpy: 1D pandas === series
# list[[]] numpy : 2D pandas ==== dataframe\

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sys
bank=pd.read_csv(r"C:\Users\ADMIN\OneDrive\Documents\data science nit\Pandas\bank.csv",sep=';')
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
shape
size
head
tail
dtypes
columns
null
info

# %%
bank.shape
# Out:
# (4521, 17)

# %%
bank.size
# Out:
# 76857

# %%
bank.head(5)
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank.tail(10)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4511   46    blue-collar  married  secondary      no      668     yes   no
# 4512   40    blue-collar  married  secondary      no     1100     yes   no
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4514   38    blue-collar  married  secondary      no     1205     yes   no
# 4515   32       services   single  secondary      no      473     yes   no
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
bank.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
bank.columns.tolist()
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
bank.isnull
# Out:
# <bound method DataFrame.isnull of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank.values
# Out:
# array([[30, 'unemployed', 'married', ..., 0, 'unknown', 'no'],
#        [33, 'services', 'married', ..., 4, 'failure', 'no'],
#        [35, 'management', 'single', ..., 1, 'failure', 'no'],
#        ...,
#        [57, 'technician', 'married', ..., 0, 'unknown', 'no'],
#        [28, 'blue-collar', 'married', ..., 3, 'other', 'no'],
#        [44, 'entrepreneur', 'single', ..., 7, 'other', 'no']],
#       shape=(4521, 17), dtype=object)

# %%
bank.iloc[2:5,6:9]
# Out:
#   housing loan   contact
# 2     yes   no  cellular
# 3     yes  yes   unknown
# 4     yes   no   unknown

# %%
bank.iloc[2:5,6:9]
cols=['housing','loan']
bank.loc[1:,cols]
# Out:
#      housing loan
# 1        yes  yes
# 2        yes   no
# 3        yes  yes
# 4        yes   no
# 5         no   no
# ...      ...  ...
# 4516     yes   no
# 4517     yes  yes
# 4518      no   no
# 4519      no   no
# 4520     yes  yes
#
# [4520 rows x 2 columns]

# %%
bank.iloc[[10,20,30]]
# Out:
#     age         job   marital  education default  balance housing loan  \
# 10   39    services   married  secondary      no     9374     yes   no
# 20   38  management  divorced    unknown      no        0     yes   no
# 30   68     retired  divorced  secondary      no     4189      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 10    unknown   20   may       273         1     -1         0  unknown   no
# 20   cellular   18   nov        96         2     -1         0  unknown   no
# 30  telephone   14   jul       897         2     -1         0  unknown  yes

# %%
bank.iloc[[10,20,30],[1,5]]
# Out:
#            job  balance
# 10    services     9374
# 20  management        0
# 30     retired     4189

# %%
bank.iloc[[10,20,30,40],5]
# Out:
# 10     9374
# 20        0
# 30     4189
# 40    11971
# Name: balance, dtype: int64

# %%
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank.loc[::]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank.iloc[1:4,2:7]
# Out:
#    marital  education default  balance housing
# 1  married  secondary      no     4789     yes
# 2   single   tertiary      no     1350     yes
# 3  married   tertiary      no     1476     yes
